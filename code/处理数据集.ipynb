# %%
import pandas as pd

# %%
df = pd.read_csv('guangxi_result-5130.csv')

# %%
df
# Out:
#                                  索引号 效力状态            发文单位         成文日期  \
# 0     11450000007565768W/2021-404532   有效     广西壮族自治区人民政府  2021年10月22日
# 1                                NaN  NaN             NaN          NaN
# 2                                NaN  NaN             NaN          NaN
# 3     11450000007565768W/2021-399616   有效  广西壮族自治区人民政府办公厅  2021年10月30日
# 4     11450000007565768W/2021-399550   有效     广西壮族自治区人民政府   2021年11月4日
# ...                              ...  ...             ...          ...
# 5431           000014349/2020-406165   有效  广西壮族自治区人民政府办公厅    2003年7月4日
# 5432           000014349/2020-405060   有效  广西壮族自治区人民政府办公厅  2006年12月14日
# 5433                             NaN  NaN             NaN          NaN
# 5434           000014349/2020-405058   有效  广西壮族自治区人民政府办公厅  2006年12月14日
# 5435                             NaN  NaN             NaN          NaN
#
#                                                      标题                 发文字号  \
# ...

# %%
df.shape
# Out:
# (5436, 8)

# %%
df.dropna(how='all', inplace=True)

# %%
df
# Out:
#                                  索引号 效力状态            发文单位         成文日期  \
# 0     11450000007565768W/2021-404532   有效     广西壮族自治区人民政府  2021年10月22日
# 3     11450000007565768W/2021-399616   有效  广西壮族自治区人民政府办公厅  2021年10月30日
# 4     11450000007565768W/2021-399550   有效     广西壮族自治区人民政府   2021年11月4日
# 6     11450000007565768W/2021-391462   有效  广西壮族自治区人民政府办公厅  2021年10月29日
# 7     11450000007565768W/2021-391425   有效  广西壮族自治区人民政府办公厅  2021年10月29日
# ...                              ...  ...             ...          ...
# 5431           000014349/2020-406165   有效  广西壮族自治区人民政府办公厅    2003年7月4日
# 5432           000014349/2020-405060   有效  广西壮族自治区人民政府办公厅  2006年12月14日
# 5433                             NaN  NaN             NaN          NaN
# 5434           000014349/2020-405058   有效  广西壮族自治区人民政府办公厅  2006年12月14日
# 5435                             NaN  NaN             NaN          NaN
#
#                                                      标题                 发文字号  \
# ...

# %%
df.shape
# Out:
# (5035, 8)

# %%
df['效力状态'].value_counts()
# Out:
# 有效       4539
# 失效        389
# 废止          2
# 对产品有"       1
# 稳"          1
# Name: 效力状态, dtype: int64

# %%
df['索引号'].isnull().sum()
# Out:
# 1593

# %%
data = df[(df['效力状态'] == '有效') & (df['索引号'].notnull())]

# %%
data = data[data['发文字号'].map(lambda x: '函' in x)]

# %%
data
# Out:
#                                  索引号 效力状态             发文单位         成文日期  \
# 4     11450000007565768W/2021-399550   有效      广西壮族自治区人民政府   2021年11月4日
# 13    11450000007565768W/2021-378746   有效      广西壮族自治区人民政府   2021年11月1日
# 14    11450000007565768W/2021-378743   有效      广西壮族自治区人民政府  2021年10月27日
# 20    11450000007565768W/2021-372477   有效      广西壮族自治区人民政府  2021年10月24日
# 37    11450000007565768W/2021-347161   有效   广西壮族自治区人民政府办公厅   2021年10月7日
# ...                              ...  ...              ...          ...
# 1003           000014349/2020-406269   有效      广西壮族自治区人民政府   2019年1月31日
# 1004           000014349/2020-406268   有效      广西壮族自治区人民政府   2019年1月26日
# 1005           000014349/2020-406267   有效  广西壮族自治区人民政府关于同意   2019年1月24日
# 1816           000014349/2020-408981   有效   广西壮族自治区人民政府办公厅   2017年6月23日
# 1817           000014349/2020-403364   有效   广西壮族自治区人民政府办公厅   2017年6月23日
#
#                                                      标题                发文字号  \
# ...

# %%
data.shape
# Out:
# (94, 8)

# %%
data.to_csv('data.csv', index=False)
